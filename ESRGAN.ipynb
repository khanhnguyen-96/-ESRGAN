# %% [markdown]
# <a href="https://colab.research.google.com/github/nnkti18/-ESRGAN/blob/master/ESRGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/grive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/grive

# %%
# !pip install tensorboardX
# Out:
# ...
#     100% |████████████████████████████████| 133kB 4.7MB/s
# ...

# %%
cd /content/grive/My Drive/LVTN/SuperResolution/ESRGAN/-ESRGAN
# Out:
# /content/grive/My Drive/LVTN/SuperResolution/ESRGAN/-ESRGAN

# %%
# !git pull
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/nnkti18/-ESRGAN
#    ff47dc8..4477c9b  master     -> origin/master
# Updating ff47dc8..4477c9b
# Fast-forward
#  ESRGAN.ipynb | 1796 +++++++++++++++++++++++++++++++++++++++++++++++++++++++++-
#  1 file changed, 1779 insertions(+), 17 deletions(-)

# %%
# !python train.py -opt ./options/train/train_ESRGAN.json
# Out:
# export CUDA_VISIBLE_DEVICES=0
# Path already exists. Rename it to [/content/grive/My Drive/LVTN/SuperResolution/ESRGAN/-ESRGAN/experiments/RRDB_ESRGAN_x4_celeba_val_1000_archived_190320-134337]
# 19-03-20 13:43:37.124 - INFO:   name: RRDB_ESRGAN_x4_celeba_val_1000
#   use_tb_logger: True
#   model: srragan
#   scale: 4
#   gpu_ids: [0]
#   datasets:[
#     train:[
#       name: celeba_val_1000
#       mode: LRHR
#       dataroot_HR: /content/grive/My Drive/LVTN/SuperResolution/ESRGAN/Dataset/celeba_val_1000_HR.lmdb
#       dataroot_LR: /content/grive/My Drive/LVTN/SuperResolution/ESRGAN/Dataset/celeba_val_1000_LR_8x.lmdb
#       subset_file: None
#       use_shuffle: True
#       n_workers: 8
#       batch_size: 16
#       HR_size: 128
#       use_flip: True
#       use_rot: True
#       phase: train
#       scale: 4
#       data_type: lmdb
#     ]
#     val:[
#       name: helen_val_50
#       mode: LRHR
# ...
