# %% [markdown]
# <a href="https://colab.research.google.com/github/nnkti18/-ESRGAN/blob/master/ESRGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# !pip install tensorboardX
# !git clone https://github.com/nnkti18/-ESRGAN.git

# %%
cd /content/gdrive/My Drive/LVTN/SuperResolution/SR_models/
# Out:
# /content/gdrive/My Drive/LVTN/SuperResolution/SR_models

# %%
mkdir /content/dataset && mkdir /content/dataset/img_align_celeba_png_set_1_HR && cp -r ./Dataset/img_align_celeba_png_set_1_HR /content/dataset

# %%
cd /content/-ESRGAN
# Out:
# /content/-ESRGAN

# %%
# !git reset --hard
# !git pull
# Out:
# HEAD is now at 1ce16bb fix sys path
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0
# Unpacking objects: 100% (4/4), done.
# From https://github.com/nnkti18/-ESRGAN
#    1ce16bb..e85a609  master     -> origin/master
# Updating 1ce16bb..e85a609
# Fast-forward
#  scripts/generate_LR_bic_Pillow.py | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %%
# !python ./scripts/generate_LR_bic_Pillow.py
# Out:
# terminal width is too small ({}), please consider widen the terminal for better progressbar visualization
# [          ] 0/9001, elapsed: 0s, ETA:
# Start...
# [----------] 1/9001, 6364.6 task/s, elapsed: 0s, ETA:     1s
# Read /content/dataset/img_align_celeba_png_set_1_HR/000001.png
# [----------] 2/9001, 188.1 task/s, elapsed: 0s, ETA:    48s
# Read /content/dataset/img_align_celeba_png_set_1_HR/000002.png
# [----------] 3/9001, 221.9 task/s, elapsed: 0s, ETA:    41s
# Read /content/dataset/img_align_celeba_png_set_1_HR/000003.png
# [----------] 4/9001, 246.5 task/s, elapsed: 0s, ETA:    37s
# Read /content/dataset/img_align_celeba_png_set_1_HR/000004.png
# [----------] 5/9001, 267.6 task/s, elapsed: 0s, ETA:    34s
# Read /content/dataset/img_align_celeba_png_set_1_HR/000005.png
# [----------] 6/9001, 279.1 task/s, elapsed: 0s, ETA:    32s
# Read /content/dataset/img_align_celeba_png_set_1_HR/000006.png
# [----------] 7/9001, 292.7 task/s, elapsed: 0s, ETA:    31s
# ...

# %%
# !cp {img_align_celeba_png_set_1_HR,img_align_celeba_png_set_1_LRx4}.zip ./

# %%
# !python train.py -opt ./options/train/train_ESRGAN.json

# %%
# !ln -sf /opt/bin/nvidia-smi /usr/bin/nvidia-smi
# !pip install gputil
# !pip install psutil
# !pip install humanize
import psutil
import humanize`
import os
import GPUtil as GPU
GPUs = GPU.getGPUs()
# XXX: only one GPU on Colab and isn’t guaranteed
gpu = GPUs[0]
def printm():
 process = psutil.Process(os.getpid())
 print("Gen RAM Free: " + humanize.naturalsize( psutil.virtual_memory().available ), " | Proc size: " + humanize.naturalsize( process.memory_info().rss))
 print("GPU RAM Free: {0:.0f}MB | Used: {1:.0f}MB | Util {2:3.0f}% | Total {3:.0f}MB".format(gpu.memoryFree, gpu.memoryUsed, gpu.memoryUtil*100, gpu.memoryTotal))
printm()
# Out:
# ...
# Gen RAM Free: 12.9 GB  | Proc size: 143.4 MB
# GPU RAM Free: 11441MB | Used: 0MB | Util   0% | Total 11441MB

# %%
# !kill -9 -1

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         359G   24G  317G   7% /
# tmpfs           6.4G     0  6.4G   0% /dev
# tmpfs           6.4G     0  6.4G   0% /sys/fs/cgroup
# tmpfs           6.4G   12K  6.4G   1% /var/colab
# /dev/sda1       365G   27G  339G   8% /opt/bin
# shm             6.0G     0  6.0G   0% /dev/shm
# tmpfs           6.4G     0  6.4G   0% /sys/firmware
# drive           359G   41G  319G  12% /content/gdrive
